# %%
import json
import string
import random
from flask import Flask, request, jsonify
from flask_cors import CORS

import nltk
import numpy as np
from nltk.stem import WordNetLemmatizer
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout
import nltk
nltk.download("punkt")
nltk.download("wordnet")
nltk.download('omw-1.4')
# Out:
# 2023-07-10 23:16:56.902582: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/rajapaksha/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/rajapaksha/nltk_data...
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/rajapaksha/nltk_data...
# True

# %%
from nltk.stem import WordNetLemmatizer
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout
import nltk
nltk.download("punkt")
nltk.download("wordnet")
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/rajapaksha/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/rajapaksha/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/rajapaksha/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
data_file = open('intents.json').read()
data = json.loads(data_file)

# %%
words = []
classes = []
data_X = []
data_y = []

for intent in data["intents"]:
  for pattern in intent["patterns"]:
    tokens = nltk.word_tokenize(pattern)
    words.extend(tokens)
    data_X.append(pattern)
    data_y.append(intent["tag"]),
  if intent["tag"] not in classes:
    classes.append(intent["tag"])

lemmatizer = WordNetLemmatizer()

words = [lemmatizer.lemmatize(word.lower()) for word in words if word not in string.punctuation]
words = sorted(set(words))
classes = sorted(set(classes))

# %%
training = []
out_empty = [0]*len(classes)
for idx, doc in enumerate(data_X):
  bow = []
  text = lemmatizer.lemmatize(doc.lower())
  for word in words:
    bow.append(1) if word in text else bow.append(0)
  output_row = list(out_empty)
  output_row[classes.index(data_y[idx])] = 1
  training.append([bow, output_row])
random.shuffle(training)
training = np.array(training, dtype=object)
train_X = np.array(list(training[:,0]))
train_Y = np.array(list(training[:,1]))

# %%
model = Sequential()
model.add(Dense(128, input_shape = (len(train_X[0]),), activation = "relu"))
model.add(Dropout(0.5))
model.add(Dense(64, activation = "relu"))
model.add(Dropout(0.5))
model.add(Dense(len(train_Y[0]), activation = "softmax"))
adam = tf.keras.optimizers.legacy.Adam(learning_rate = 0.01, decay = 1e-6)
model.compile(loss = "categorical_crossentropy",
              optimizer = adam,
              metrics = ["accuracy"]
              )
print(model.summary())
model.fit(x=train_X, y=train_Y, epochs = 150, verbose = 1)
# Out:
# 2023-07-10 23:22:09.041947: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               26624
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 24)                1560
#
# =================================================================
# Total params: 36,440
# Trainable params: 36,440
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/150
# 4/4 [==============================] - 2s 7ms/step - loss: 3.2704 - accuracy: 0.0374
# Epoch 2/150
# 4/4 [==============================] - 0s 31ms/step - loss: 3.0625 - accuracy: 0.1121
# Epoch 3/150
# 4/4 [==============================] - 0s 15ms/step - loss: 2.9377 - accuracy: 0.1682
# Epoch 4/150
# 4/4 [==============================] - 0s 9ms/step - loss: 2.7306 - accuracy: 0.2710
# Epoch 5/150
# 4/4 [==============================] - 0s 11ms/step - loss: 2.5794 - accuracy: 0.3364
# Epoch 6/150
# 4/4 [==============================] - 0s 13ms/step - loss: 2.3575 - accuracy: 0.3271
# Epoch 7/150
# 4/4 [==============================] - 0s 8ms/step - loss: 2.1680 - accuracy: 0.3645
# Epoch 8/150
# 4/4 [==============================] - 0s 8ms/step - loss: 1.8062 - accuracy: 0.4206
# Epoch 9/150
# 4/4 [==============================] - 0s 5ms/step - loss: 1.7304 - accuracy: 0.4953
# Epoch 10/150
# 4/4 [==============================] - 0s 40ms/step - loss: 1.5480 - accuracy: 0.5421
# Epoch 11/150
# 4/4 [==============================] - 0s 13ms/step - loss: 1.3349 - accuracy: 0.5981
# Epoch 12/150
# 4/4 [==============================] - 0s 8ms/step - loss: 1.1391 - accuracy: 0.6449
# Epoch 13/150
# 4/4 [==============================] - 0s 8ms/step - loss: 0.9855 - accuracy: 0.7290
# Epoch 14/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.9631 - accuracy: 0.6449
# Epoch 15/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.7235 - accuracy: 0.7477
# Epoch 16/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.7982 - accuracy: 0.7290
# Epoch 17/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.7282 - accuracy: 0.7944
# Epoch 18/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6035 - accuracy: 0.7850
# Epoch 19/150
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6777 - accuracy: 0.7850
# Epoch 20/150
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6932 - accuracy: 0.7664
# Epoch 21/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.5760 - accuracy: 0.8224
# Epoch 22/150
# 4/4 [==============================] - 0s 8ms/step - loss: 0.5211 - accuracy: 0.8131
# Epoch 23/150
# 4/4 [==============================] - 0s 10ms/step - loss: 0.5063 - accuracy: 0.8505
# Epoch 24/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.5333 - accuracy: 0.8224
# Epoch 25/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3119 - accuracy: 0.8972
# Epoch 26/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.4900 - accuracy: 0.8411
# Epoch 27/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3765 - accuracy: 0.8879
# Epoch 28/150
# 4/4 [==============================] - 0s 9ms/step - loss: 0.4203 - accuracy: 0.8972
# Epoch 29/150
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3324 - accuracy: 0.8972
# Epoch 30/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2972 - accuracy: 0.9252
# Epoch 31/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.4871 - accuracy: 0.8505
# Epoch 32/150
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3071 - accuracy: 0.9065
# Epoch 33/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3217 - accuracy: 0.8972
# Epoch 34/150
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2227 - accuracy: 0.9346
# Epoch 35/150
# 4/4 [==============================] - 0s 10ms/step - loss: 0.2651 - accuracy: 0.9159
# Epoch 36/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2425 - accuracy: 0.9065
# Epoch 37/150
# 4/4 [==============================] - 0s 10ms/step - loss: 0.4524 - accuracy: 0.8692
# Epoch 38/150
# 4/4 [==============================] - 0s 9ms/step - loss: 0.2449 - accuracy: 0.9065
# Epoch 39/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.4045 - accuracy: 0.8692
# Epoch 40/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2045 - accuracy: 0.9346
# Epoch 41/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3717 - accuracy: 0.8785
# Epoch 42/150
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3004 - accuracy: 0.9065
# Epoch 43/150
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3198 - accuracy: 0.9065
# Epoch 44/150
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2694 - accuracy: 0.9346
# Epoch 45/150
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3261 - accuracy: 0.8785
# Epoch 46/150
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1734 - accuracy: 0.9252
# Epoch 47/150
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2021 - accuracy: 0.9346
# Epoch 48/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2036 - accuracy: 0.9346
# Epoch 49/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1858 - accuracy: 0.9346
# Epoch 50/150
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3564 - accuracy: 0.8972
# Epoch 51/150
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1225 - accuracy: 0.9720
# Epoch 52/150
# 4/4 [==============================] - 0s 9ms/step - loss: 0.4354 - accuracy: 0.8879
# Epoch 53/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1283 - accuracy: 0.9533
# Epoch 54/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2149 - accuracy: 0.9626
# Epoch 55/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3156 - accuracy: 0.9159
# Epoch 56/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3330 - accuracy: 0.8879
# Epoch 57/150
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1901 - accuracy: 0.9065
# Epoch 58/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1981 - accuracy: 0.9533
# Epoch 59/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2057 - accuracy: 0.9346
# Epoch 60/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1130 - accuracy: 0.9720
# Epoch 61/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1948 - accuracy: 0.9533
# Epoch 62/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1835 - accuracy: 0.9346
# Epoch 63/150
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2043 - accuracy: 0.9252
# Epoch 64/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1582 - accuracy: 0.9439
# Epoch 65/150
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1337 - accuracy: 0.9439
# Epoch 66/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1274 - accuracy: 0.9346
# Epoch 67/150
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3272 - accuracy: 0.9159
# Epoch 68/150
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2018 - accuracy: 0.9346
# Epoch 69/150
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2980 - accuracy: 0.9252
# Epoch 70/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2484 - accuracy: 0.9439
# Epoch 71/150
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1983 - accuracy: 0.9346
# Epoch 72/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1891 - accuracy: 0.9533
# Epoch 73/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1615 - accuracy: 0.9439
# Epoch 74/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1689 - accuracy: 0.9346
# Epoch 75/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0950 - accuracy: 0.9533
# Epoch 76/150
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1324 - accuracy: 0.9720
# Epoch 77/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2817 - accuracy: 0.9346
# Epoch 78/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1441 - accuracy: 0.9533
# Epoch 79/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3227 - accuracy: 0.8972
# Epoch 80/150
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2173 - accuracy: 0.9159
# Epoch 81/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0707 - accuracy: 0.9813
# Epoch 82/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1956 - accuracy: 0.9065
# Epoch 83/150
# 4/4 [==============================] - 0s 10ms/step - loss: 0.2090 - accuracy: 0.9346
# Epoch 84/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0892 - accuracy: 0.9533
# Epoch 85/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1850 - accuracy: 0.9346
# Epoch 86/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1007 - accuracy: 0.9626
# Epoch 87/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1400 - accuracy: 0.9626
# Epoch 88/150
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1298 - accuracy: 0.9533
# Epoch 89/150
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1394 - accuracy: 0.9626
# Epoch 90/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1035 - accuracy: 0.9626
# Epoch 91/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1959 - accuracy: 0.9065
# Epoch 92/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2537 - accuracy: 0.9065
# Epoch 93/150
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1709 - accuracy: 0.9252
# Epoch 94/150
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0841 - accuracy: 0.9533
# Epoch 95/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1407 - accuracy: 0.9720
# Epoch 96/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2038 - accuracy: 0.9252
# Epoch 97/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1496 - accuracy: 0.9346
# Epoch 98/150
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1088 - accuracy: 0.9533
# Epoch 99/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0857 - accuracy: 0.9720
# Epoch 100/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1229 - accuracy: 0.9533
# Epoch 101/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3350 - accuracy: 0.9252
# Epoch 102/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2138 - accuracy: 0.9252
# Epoch 103/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1323 - accuracy: 0.9626
# Epoch 104/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1728 - accuracy: 0.9533
# Epoch 105/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1503 - accuracy: 0.9439
# Epoch 106/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1542 - accuracy: 0.9533
# Epoch 107/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0682 - accuracy: 0.9720
# Epoch 108/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1882 - accuracy: 0.9252
# Epoch 109/150
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1193 - accuracy: 0.9533
# Epoch 110/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1082 - accuracy: 0.9533
# Epoch 111/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2955 - accuracy: 0.9346
# Epoch 112/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1954 - accuracy: 0.9439
# Epoch 113/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0889 - accuracy: 0.9626
# Epoch 114/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0918 - accuracy: 0.9907
# Epoch 115/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1465 - accuracy: 0.9439
# Epoch 116/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2429 - accuracy: 0.9252
# Epoch 117/150
# 4/4 [==============================] - 0s 9ms/step - loss: 0.2830 - accuracy: 0.9065
# Epoch 118/150
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1887 - accuracy: 0.9252
# Epoch 119/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1896 - accuracy: 0.9252
# Epoch 120/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1291 - accuracy: 0.9533
# Epoch 121/150
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2122 - accuracy: 0.9065
# Epoch 122/150
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0782 - accuracy: 0.9533
# Epoch 123/150
# 4/4 [==============================] - 0s 10ms/step - loss: 0.2342 - accuracy: 0.9252
# Epoch 124/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1375 - accuracy: 0.9626
# Epoch 125/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3646 - accuracy: 0.9065
# Epoch 126/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1352 - accuracy: 0.9720
# Epoch 127/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1266 - accuracy: 0.9533
# Epoch 128/150
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1890 - accuracy: 0.9439
# Epoch 129/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4105 - accuracy: 0.9159
# Epoch 130/150
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1024 - accuracy: 0.9720
# Epoch 131/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3225 - accuracy: 0.8972
# Epoch 132/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1190 - accuracy: 0.9533
# Epoch 133/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1458 - accuracy: 0.9439
# Epoch 134/150
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1298 - accuracy: 0.9439
# Epoch 135/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1336 - accuracy: 0.9626
# Epoch 136/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1770 - accuracy: 0.9346
# Epoch 137/150
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2168 - accuracy: 0.9252
# Epoch 138/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2092 - accuracy: 0.9346
# Epoch 139/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1344 - accuracy: 0.9533
# Epoch 140/150
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1718 - accuracy: 0.9439
# Epoch 141/150
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1411 - accuracy: 0.9626
# Epoch 142/150
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1389 - accuracy: 0.9720
# Epoch 143/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2313 - accuracy: 0.9159
# Epoch 144/150
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0847 - accuracy: 0.9626
# Epoch 145/150
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1882 - accuracy: 0.9252
# Epoch 146/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1655 - accuracy: 0.9346
# Epoch 147/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1891 - accuracy: 0.9439
# Epoch 148/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1758 - accuracy: 0.9159
# Epoch 149/150
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1465 - accuracy: 0.9626
# Epoch 150/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1229 - accuracy: 0.9533

# %%
def clean_text(text):
  tokens = nltk.word_tokenize(text)
  tokens = [lemmatizer.lemmatize(word) for word in tokens]
  return tokens

def bag_of_words(text, vocab):
  tokens = clean_text(text)
  bow = [0]*len(vocab)
  for w in tokens:
    for idx, word in enumerate(vocab):
      if word == w:
        bow[idx] = 1
  return np.array(bow)

def pred_class(text, vocab, labels):
  bow = bag_of_words(text, vocab)
  result = model.predict(np.array([bow]))[0]
  thresh = 0.5
  y_pred = [[indx, res] for indx, res in enumerate(result) if res > thresh]
  y_pred.sort(key=lambda x: x[1], reverse = True)
  return_list = []
  for r in y_pred:
    return_list.append(labels[r[0]])
    return return_list
  
def get_response(intents_list, intents_json):
  if not isinstance(intents_list, list):
    intents_list = []

  if len(intents_list) == 0:
    result = "Sorry! I don't understand."
  else:
    tag = intents_list[0]
    list_of_intents= intents_json["intents"]
    for i in list_of_intents:
      if i["tag"] == tag:
        result = random.choice(i["responses"])
        break
  return result

# %%
app = Flask(__name__)
CORS(app)

@app.route('/chat', methods=['POST'])
def chat():
    message = request.json['message']
    intents = pred_class(message, words, classes)
    result = get_response(intents, data)
    response = jsonify({'response': result})
    response.headers.add('Access-Control-Allow-Origin', '*')
    return response

if __name__ == '__main__':
    app.run(debug=True, use_reloader=False)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [10/Jul/2023 23:22:34] "GET / HTTP/1.1" 404 -
# 127.0.0.1 - - [10/Jul/2023 23:22:35] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [10/Jul/2023 23:22:58] "GET /chat HTTP/1.1" 405 -
# 127.0.0.1 - - [10/Jul/2023 23:24:10] "GET /chat HTTP/1.1" 405 -
# 127.0.0.1 - - [10/Jul/2023 23:24:19] "GET /chat HTTP/1.1" 405 -
# 127.0.0.1 - - [10/Jul/2023 23:24:31] "GET /chat HTTP/1.1" 405 -
# 1/1 [==============================] - 0s 332ms/step
# 127.0.0.1 - - [10/Jul/2023 23:28:07] "POST /chat HTTP/1.1" 200 -
